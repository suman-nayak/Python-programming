# %%
n = int(input("Enter n: "))
sum = 0
i = 1
while i <= n:
    sum = sum + i
    i = i + 1
print("sum is: ",sum)
# Out:
# Enter n: 5
# sum is:  15

# %%
n = int(input("Enter a Nmber"))
while n > 10:
    sqr = n**2
    i = i + 1
print("Square is: ", sqr)

# %%
sum1 = 0
x = range(10)
for val in x:
    sum1 = sum1 + val
print("The sum is: ",sum1)
# Out:
# The sum is:  45

# %%
num = int(input("Enter the range: "))
intr = int(input("Enter the interva: "))
sum = 0
x = range(num,intr + 1)
for val in x:
    if val % 2 != 0:
        sum = sum + val
print("The sum is: ", sum)
# Out:
# Enter the range: 2
# Enter the interva: 5
# The sum is:  8

# %%
x = range(1, 10, 2)
for v in x:
    print(x)
# Out:
# range(1, 10, 2)
# range(1, 10, 2)
# range(1, 10, 2)
# range(1, 10, 2)
# range(1, 10, 2)

# %%
n = int(input("Enter a number: "))
num = int(input("Enter the range: "))
intr = int(input("Enter the interval: "))
x = range(num, intr + 1)
for i in x:
    y = range(2, )

# %%
for i in range(4):
    for j in range(4):
        if j==2:
            break
    print(i, j)
# Out:
# 0 2
# 1 2
# 2 2
# 3 2

# %%
for ch in "python":
    if ch == "h":
        break
    print(ch)
print("End")
# Out:
# p
# y
# t
# End

# %%
for i in range(4):
    if i == 2:
        continue
print(i)
# Out:
# 3

# %%
number = 6

while number > 0:
    number -= 1
    if number == 2:
        continue
    print(number)

print("Loop ended")
# Out:
# 5
# 4
# 3
# 1
# 0
# Loop ended
