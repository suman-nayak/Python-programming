# %%
l1 = [5, 6, 7, 30, -5, 19]
x = l1.pop(2)
y = del l1[2]
z = l1.remove(30)
print(x)
print(y)
print(z)
# Out:
#   File "C:\Users\SILICON\AppData\Local\Temp\ipykernel_12456\3259819475.py", line 3
#     y = del l1[2]
#         ^
# SyntaxError: invalid syntax

# %%
l1 = [5, 6, 7, 30, -5, 19]
x = l1.pop(2)  
y = del l1[2]         
z = l1.remove(30)  
print(x)
print(y)  
print(z)
# Out:
#   File "C:\Users\SILICON\AppData\Local\Temp\ipykernel_12456\1483653011.py", line 3
#     y = del l1[2]          # now l1[2] is 30, so this removes 30
#         ^
# SyntaxError: invalid syntax

# %%
l1 = [5, 6, 7, 30, -5, 19]
x = l1.pop(2)      
#y = l1.del[2]     
z = l1.remove(-5)  
print(x) 
#print(l1.del[2]) 
print(z) 
print(l1)
# Out:
# 7
# None
# [5, 6, 30, 19]

# %%
l1 = [12,1,22,43,4,5]
for i in l1:
    if i % 2 == 0:
        print(i)
# Out:
# 12
# 22
# 4

# %%
l1 = [12,1,22,43,4,5]
l2 = [x for x in l1 if x % 2 == 0]
l3 = []
print(l2)
# Out:
# [12, 22, 4]

# %%
#Tuple1 = () #empty tuple

Tuple2 = ('zooming', 'For') #tuple with strings

list1 = [1, 2, 4, 5, 6]
Tuple3 = tuple (list1) #tuple with the use of list

Tuple4 = ('zooming',) * 3 #tuple with repetition

Tuple5 = (5, 'Welcome', 7, 'zooming') #tuple with mixed datatypes
