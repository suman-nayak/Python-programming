# %%
num = int(input("Enter a number: "))
large = 0
small = 0
while num > 0:
    rem = num % 10
    if (rem < small):
        small = rem
    elif(rem > large):
        large = rem
    num = num // 10
print("The large number is: ", large)
print("The small number is: ", small)
# Out:
# Enter a number: 0324234
# The large number is:  4
# The small number is:  0

# %%
num = int(input("Enter a number: "))
count = 0
while digit <= 9:
    temp = num
    while temp > 0:
        r = temp % 10
        temp = temp // 10
        if (r == digit):
            count = count + 1
        if count > 0:
            print(digit, "=", count)
        digit = digit + 1
# Out:
# Enter a number: 111
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8408\2130504034.py in <module>
#       1 num = int(input("Enter a number: "))
#       2 count = 0
# ----> 3 while digit <= 9:
#       4     temp = num
#       5     while temp > 0:
#
# NameError: name 'digit' is not defined
